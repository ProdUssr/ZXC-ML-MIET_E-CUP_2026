# %% [markdown]
# # Phase 0 EDA
#
# Reproducible facts and validation metrics are recorded in `docs/phase0_report.md`. This intentionally empty starter notebook avoids embedding the dataset or outputs in the repository.
